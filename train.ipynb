# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'].value_counts()
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
median_age = df['Age'].median()
df['Age'] = df['Age'].fillna(median_age)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
plt.figure(figsize = (4,4))
ax = sns.countplot(x = "Pclass", data = df, hue = "Sex")
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
plt.title("abc")
plt.show()

# %% [markdown]
# #Correlation Heatmap

# %%
plt.figure(figsize=(8,5))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

print("\n🔎 Heatmap Observations:")
print("- Survival is negatively correlated with Pclass → higher class = better survival chances.")
print("- Survival is positively correlated with Fare → higher fare = higher chance of survival.")
print("- Age has very weak correlation with survival.")
print("- SibSp and Parch are moderately correlated (family size factor).")
# Out:
# 🔎 Heatmap Observations:
# - Survival is negatively correlated with Pclass → higher class = better survival chances.
# - Survival is positively correlated with Fare → higher fare = higher chance of survival.
# - Age has very weak correlation with survival.
# - SibSp and Parch are moderately correlated (family size factor).

# %% [markdown]
# #Histogram

# %%
df['Age'].hist(bins=30, edgecolor='black')
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

print("\n🔎 Age Histogram Observations:")
print("- Most passengers were between 20–40 years old.")
print("- Very few children (<10) and elderly (>60).")
# Out:
# 🔎 Age Histogram Observations:
# - Most passengers were between 20–40 years old.
# - Very few children (<10) and elderly (>60).

# %%
df['Fare'].hist(bins=30, edgecolor='black')
plt.title("Fare Distribution")
plt.xlabel("Fare")
plt.ylabel("Count")
plt.show()

print("\n🔎 Fare Histogram Observations:")
print("- Most passengers paid a low fare (<100).")
print("- Few passengers paid very high fares (outliers).")
# Out:
# 🔎 Fare Histogram Observations:
# - Most passengers paid a low fare (<100).
# - Few passengers paid very high fares (outliers).

# %% [markdown]
# #Boxplot

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x="Survived", y="Age", data=df)
plt.title("Age vs Survival")
plt.show()

print("\n🔎 Boxplot (Age vs Survival) Observations:")
print("- Survivors had a wide age range, but more younger passengers survived.")
print("- Median age of survivors is slightly lower than non-survivors.")
# Out:
# 🔎 Boxplot (Age vs Survival) Observations:
# - Survivors had a wide age range, but more younger passengers survived.
# - Median age of survivors is slightly lower than non-survivors.

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x="Pclass", y="Fare", data=df)
plt.title("Fare vs Passenger Class")
plt.show()

print("\n🔎 Boxplot (Fare vs Class) Observations:")
print("- Higher class passengers (1st class) paid much higher fares.")
print("- 3rd class passengers mostly paid very low fares.")
# Out:
# 🔎 Boxplot (Fare vs Class) Observations:
# - Higher class passengers (1st class) paid much higher fares.
# - 3rd class passengers mostly paid very low fares.

# %% [markdown]
# #Scatterplot

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(x="Age", y="Fare", hue="Survived", data=df)
plt.title("Age vs Fare (Survival)")
plt.show()

print("\n🔎 Scatterplot (Age vs Fare with Survival) Observations:")
print("- Survivors are more concentrated among higher fare passengers.")
print("- Younger passengers also have slightly better survival chances.")
print("- Many low-fare 3rd class passengers did not survive.")
# Out:
# 🔎 Scatterplot (Age vs Fare with Survival) Observations:
# - Survivors are more concentrated among higher fare passengers.
# - Younger passengers also have slightly better survival chances.
# - Many low-fare 3rd class passengers did not survive.

# %% [markdown]
# #Final Summary

# %%
print("\n📊 Summary of Findings:")
print("1. 1st class passengers had higher survival rates, while 3rd class had the lowest.")
print("2. Higher fare strongly increased survival chances (wealthier passengers benefited).")
print("3. Age had weak correlation; children survived slightly more often, but overall effect was small.")
print("4. Family size mattered — small families had better survival than large families.")
print("5. Most passengers were young adults (20–40) and paid low fares; many of them in 3rd class did not survive.")
# Out:
# 📊 Summary of Findings:
# 1. 1st class passengers had higher survival rates, while 3rd class had the lowest.
# 2. Higher fare strongly increased survival chances (wealthier passengers benefited).
# 3. Age had weak correlation; children survived slightly more often, but overall effect was small.
# 4. Family size mattered — small families had better survival than large families.
# 5. Most passengers were young adults (20–40) and paid low fares; many of them in 3rd class did not survive.
